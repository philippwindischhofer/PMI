# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
from matplotlib.mlab import griddata

# %%
def prepare_data(n_samples):
    data = []
    labels = []
    nuisances = []
    
    for i in range(n_samples):
        sig_bkg = np.random.uniform(low = 0.0, high = 1.0, size = 1)
        if sig_bkg > 0.5:
            nuisance = np.random.uniform(low = 0.0, high = 2.0, size = 1)
            data.append(np.random.multivariate_normal(mean = [0.0, nuisance], cov = np.array([[1, -0.5], [-0.5, 1]]), size = 1).flatten())
            labels.append(1.0)
        else:
            nuisance = np.random.uniform(low = 0.0, high = 2.0, size = 1)
            data.append(np.random.multivariate_normal(mean = [1.0, nuisance], cov = np.eye(2), size = 1).flatten())
            labels.append(0.0)
            
        nuisances.append(nuisance)
    data = np.array(data)
    labels = np.array(labels)
    nuisances = np.array(nuisances)
    
    return data, labels, nuisances.flatten()

# %%
num_samples = 50000
data_train, labels_train, nuisances_train = prepare_data(num_samples)
nuisances_train = np.expand_dims(nuisances_train, axis = 1)

# %%
import tensorflow as tf

# %%
import tensorflow.contrib.layers as layers

# %%
config = tf.ConfigProto(intra_op_parallelism_threads=8, inter_op_parallelism_threads=8, \
                        allow_soft_placement=True, device_count = {'CPU': 8})
sess = tf.InteractiveSession(config = config)

# %%
# batch size for evaluation of mutual entropy
MINE_batch_size = num_samples

# batch size for the training of the encoder / decoder pair
batch_size = 200

bottleneck_size = 2

# %%
data_in = tf.placeholder(tf.float32, [None, 2], name = 'data_in')
nuisances_in = tf.placeholder(tf.float32, [None, 1], name = 'nuisances_in')
labels_in = tf.placeholder(tf.int32, [None, ], name = 'labels_in')

# %%
def encoder(encoder_input):
    with tf.variable_scope("encoder"):
        lay = layers.relu(encoder_input, 20)
        lay = layers.relu(lay, 20)
        outputs = layers.linear(lay, bottleneck_size)
        
        these_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope = "encoder")
        
    return outputs, these_vars

# %%
def decoder(decoder_input):
    with tf.variable_scope("decoder"):
        lay = layers.relu(decoder_input, 20)
        lay = layers.relu(lay, 20)
        outputs = layers.linear(lay, 2)
        
        these_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope = "decoder")

    return outputs, these_vars

# %%
def MINE_network(data):
    with tf.variable_scope("MINE"):
        lay = layers.relu(data, 20)
        lay = layers.relu(lay, 20)
        outputs = layers.linear(lay, 1)
        
    these_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope = "MINE")
    
    return outputs, these_vars

# %%
encoded, encoder_vars = encoder(data_in)

# %%
decoder_output, decoder_vars = decoder(encoded)

# %%
nuisances_shuffled = tf.random.shuffle(nuisances_in)

# %%
# prepare input for MINE
data_x_combined = tf.concat([encoded, encoded], axis = 0)
data_y_combined = tf.concat([nuisances_in, nuisances_shuffled], axis = 0)

# %%
data_combined = tf.concat([data_x_combined, data_y_combined], axis = 1)
MINE_output, MINE_vars = MINE_network(data_combined)

# %%
batch_size_dyn = tf.cast(tf.math.divide(tf.shape(MINE_output)[0], 2), tf.int32)

# %%
T_xy = MINE_output[:batch_size_dyn,:]
T_x_y = MINE_output[batch_size_dyn:,:]
MINE_loss = -(tf.reduce_mean(T_xy, axis = 0) - tf.math.log(tf.reduce_mean(tf.math.exp(T_x_y), axis = 0)))
MINE_loss = MINE_loss[0]

# %%
labels_one_hot = tf.one_hot(labels_in, depth = 2)

# %%
autoencoder_loss = tf.losses.mean_squared_error(labels = data_in, predictions = decoder_output)

# %%
train_ae_pair = tf.train.AdamOptimizer(learning_rate = 0.005, beta1 = 0.9, beta2 = 0.999).minimize(autoencoder_loss, var_list = decoder_vars + encoder_vars)

# %%
MINE_regularized_autoencoder_loss = autoencoder_loss - 6 * MINE_loss

# %%
train_ae_pair_MINE_regularized = tf.train.AdamOptimizer(learning_rate = 0.0001, beta1 = 0.3, beta2 = 0.5).minimize(MINE_regularized_autoencoder_loss, var_list = decoder_vars + encoder_vars)

# %%
init_MINE = tf.variables_initializer(var_list = MINE_vars)
train_MINE = tf.train.AdamOptimizer(learning_rate = 0.01, beta1 = 0.3, beta2 = 0.5).minimize(MINE_loss, var_list = MINE_vars)

# %%
# combined training
classification_loss_evolution = []
MI_evolution = []
number_batches = 200
MINE_batches = 300

# %%
number_epochs = 20

# %%
sess.run(tf.global_variables_initializer())

# %%
# pre-train MINE
sess.run(init_MINE)
for batch in range(MINE_batches):
    sess.run(train_MINE, feed_dict = {data_in: data_train, nuisances_in: nuisances_train})

print("pre-training complete")
    
for epoch in range(number_epochs):
    print("epoch {}".format(epoch))
    # train new MINE on current encoder output
    
    for batch in range(number_batches):
        # train autoencoder with MINE regularization
        inds = np.random.choice(len(data_train), batch_size)
        data_batch = data_train[inds]
        labels_batch = labels_train[inds]
        nuisances_batch = nuisances_train[inds]

        sess.run(train_MINE, feed_dict = {data_in: data_train, nuisances_in: nuisances_train})
        sess.run(train_ae_pair_MINE_regularized, feed_dict = {data_in: data_batch, nuisances_in: nuisances_batch, labels_in: labels_batch})
    
        if not batch % 100:
            MI = -sess.run(MINE_loss, feed_dict = {data_in: data_train, nuisances_in: nuisances_train})
            class_loss = sess.run(autoencoder_loss, feed_dict = {data_in: data_train, nuisances_in: nuisances_train, labels_in: labels_train})
            global_loss = sess.run(MINE_regularized_autoencoder_loss, feed_dict = {data_in: data_train, nuisances_in: nuisances_train, labels_in: labels_train})

            print("MI = {}, ae_loss = {}, global_loss = {}".format(MI, class_loss, global_loss))
# Out:
# pre-training complete
# epoch 0
# MI = 0.12292766571044922, ae_loss = 1.9372740983963013, global_loss = 2.6553807258605957
# MI = 0.1007223129272461, ae_loss = 1.8579075336456299, global_loss = 2.4458935260772705
# epoch 1
# MI = 0.06998109817504883, ae_loss = 1.798969030380249, global_loss = 2.215233564376831
# MI = 0.03686666488647461, ae_loss = 1.752564549446106, global_loss = 1.9913655519485474
# epoch 2
# MI = 0.03442239761352539, ae_loss = 1.685936450958252, global_loss = 1.889864444732666
# MI = 0.03310966491699219, ae_loss = 1.6209704875946045, global_loss = 1.8178489208221436
# epoch 3
# MI = 0.029632568359375, ae_loss = 1.5457450151443481, global_loss = 1.7293540239334106
# MI = 0.029100418090820312, ae_loss = 1.4758931398391724, global_loss = 1.6526299715042114
# epoch 4
# MI = 0.026801109313964844, ae_loss = 1.412766933441162, global_loss = 1.573991298675537
# MI = 0.0267486572265625, ae_loss = 1.3571206331253052, global_loss = 1.5085488557815552
# epoch 5
# MI = 0.02510356903076172, ae_loss = 1.310519814491272, global_loss = 1.4553219079971313
# MI = 0.02381610870361328, ae_loss = 1.2832242250442505, global_loss = 1.4298630952835083
# epoch 6
# MI = 0.022199630737304688, ae_loss = 1.2663226127624512, global_loss = 1.4019694328308105
# MI = 0.023990631103515625, ae_loss = 1.2510870695114136, global_loss = 1.402206301689148
# epoch 7
# MI = 0.022172927856445312, ae_loss = 1.2347341775894165, global_loss = 1.3709074258804321
# MI = 0.028181076049804688, ae_loss = 1.2221256494522095, global_loss = 1.377708077430725
# epoch 8
# MI = 0.021289825439453125, ae_loss = 1.2020437717437744, global_loss = 1.336111307144165
# MI = 0.02643585205078125, ae_loss = 1.1779013872146606, global_loss = 1.3250151872634888
# epoch 9
# MI = 0.025712966918945312, ae_loss = 1.1487343311309814, global_loss = 1.2981369495391846
# MI = 0.025394439697265625, ae_loss = 1.1113638877868652, global_loss = 1.2692008018493652
# epoch 10
# MI = 0.030420303344726562, ae_loss = 1.0630276203155518, global_loss = 1.2285091876983643
# MI = 0.031414031982421875, ae_loss = 1.0089850425720215, global_loss = 1.2045302391052246
# epoch 11
# MI = 0.0354766845703125, ae_loss = 0.952599823474884, global_loss = 1.164475679397583
# MI = 0.03338623046875, ae_loss = 0.9167556166648865, global_loss = 1.1395950317382812
# epoch 12
# MI = 0.029758453369140625, ae_loss = 0.8885969519615173, global_loss = 1.0586791038513184
# MI = 0.03456878662109375, ae_loss = 0.8594169616699219, global_loss = 1.0675849914550781
# epoch 13
# MI = 0.028959274291992188, ae_loss = 0.8369561433792114, global_loss = 1.0122796297073364
# MI = 0.024738311767578125, ae_loss = 0.8143162727355957, global_loss = 0.9585347175598145
# epoch 14
# MI = 0.024143218994140625, ae_loss = 0.7925727963447571, global_loss = 0.9360359311103821
# MI = 0.02152252197265625, ae_loss = 0.781940758228302, global_loss = 0.905628502368927
# epoch 15
# MI = 0.023708343505859375, ae_loss = 0.7686271667480469, global_loss = 0.9108314514160156
# MI = 0.023525238037109375, ae_loss = 0.7509012222290039, global_loss = 0.8831720352172852
# epoch 16
# MI = 0.022121429443359375, ae_loss = 0.747950553894043, global_loss = 0.8709287643432617
# MI = 0.023853302001953125, ae_loss = 0.7291975021362305, global_loss = 0.8679685592651367
# epoch 17
# MI = 0.02300262451171875, ae_loss = 0.7257800698280334, global_loss = 0.8610721230506897
# MI = 0.021579742431640625, ae_loss = 0.7133241295814514, global_loss = 0.8443132042884827
# epoch 18
# MI = 0.02191925048828125, ae_loss = 0.7090210914611816, global_loss = 0.8490509986877441
# MI = 0.021411895751953125, ae_loss = 0.6991835236549377, global_loss = 0.8282042145729065
# epoch 19
# MI = 0.0207977294921875, ae_loss = 0.6900022625923157, global_loss = 0.8104627728462219
# MI = 0.02214813232421875, ae_loss = 0.6822711825370789, global_loss = 0.8098499178886414

# %%
data_test = np.random.uniform(low = -6, high = 6, size = [50000, 2])

# %%
pred = sess.run(encoded, feed_dict = {data_in: data_test})

# %%
xi = np.linspace(-4, 4, 1000)
yi = np.linspace(-4, 6, 1000)
zi = griddata(data_test[:, 0], data_test[:, 1], pred[:, 0], xi, yi, interp = "linear")

plt.contourf(xi, yi, zi, interp='linear', levels = 100)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:3: MatplotlibDeprecationWarning: The griddata function was deprecated in Matplotlib 2.2 and will be removed in 3.1. Use scipy.interpolate.griddata instead.
#   app.launch_new_instance()
# /home/philipp/.local/lib/python3.5/site-packages/matplotlib/contour.py:1000: UserWarning: The following kwargs were not used by contour: 'interp'
#   s)

# %%
xi = np.linspace(-4, 4, 1000)
yi = np.linspace(-4, 6, 1000)
zi = griddata(data_test[:, 0], data_test[:, 1], pred[:, 1], xi, yi, interp = "linear")

plt.contourf(xi, yi, zi, interp='linear', levels = 100)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:3: MatplotlibDeprecationWarning: The griddata function was deprecated in Matplotlib 2.2 and will be removed in 3.1. Use scipy.interpolate.griddata instead.
#   app.launch_new_instance()
# /home/philipp/.local/lib/python3.5/site-packages/matplotlib/contour.py:1000: UserWarning: The following kwargs were not used by contour: 'interp'
#   s)

# %%
plt.hexbin(x = data_train[:, 0], y = data_train[:, 1], bins = 'log', gridsize = 50)
plt.colorbar()
plt.show()

# %%
# check for pivoting property
data_test, labels_test, nuisances_test = prepare_data(num_samples)

# %%
group1 = np.logical_and(nuisances_test > 0.0, nuisances_test < 0.5)
group2 = np.logical_and(nuisances_test > 0.5, nuisances_test < 1.0)
group3 = np.logical_and(nuisances_test > 1.0, nuisances_test < 1.5)
group4 = np.logical_and(nuisances_test > 1.5, nuisances_test < 2.0)

# %%
pred1 = sess.run(encoded, feed_dict = {data_in: data_test[group1]})
pred2 = sess.run(encoded, feed_dict = {data_in: data_test[group2]})
pred3 = sess.run(encoded, feed_dict = {data_in: data_test[group3]})
pred4 = sess.run(encoded, feed_dict = {data_in: data_test[group4]})

# %%
colors = ['red', 'tan', 'lime', 'green']
plt.hist([pred1[:,1], pred2[:,1], pred3[:,1], pred4[:,1]], label = [r'$\nu_1$', r'$\nu_2$', r'$\nu_3$', r'$\nu_4$'], histtype = 'step', density = True, stacked = False, fill = False, bins = 20)
plt.legend(loc = 'upper left')
plt.show()
#plt.savefig("nomine.png")

# %%
colors = ['red', 'tan', 'lime', 'green']
plt.hist([pred1[:,0], pred2[:,0], pred3[:,0], pred4[:,0]], label = [r'$\nu_1$', r'$\nu_2$', r'$\nu_3$', r'$\nu_4$'], histtype = 'step', density = True, stacked = False, fill = False, bins = 20)
plt.legend(loc = 'upper left')
plt.show()
#plt.savefig("nomine.png")
